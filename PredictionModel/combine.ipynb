# %%
import csv
import pandas as pd
import random
import numpy as np
import math
import os

# cate="Critical"
cate="BLC-patterns"
# cate="ALC-OL-patterns"

csv_root="./data/"
time_stamp1="0412pm-0415pm"
time_stamp2="0512pm-0515pm"
time_stamp3="0527pm-0530pm"
time_stamp4="0802am-0805am"
time_stamp5="0817am-0820am"
time_stamp6="0832am-0835am"

# time_stamp1="0400pm-0412pm"
# time_stamp2="0500pm-0512pm"
# time_stamp3="0515pm-0527pm"
# time_stamp4="0750am-0802am"
# time_stamp5="0805am-0817am"
# time_stamp6="0820am-0832am"

f1=pd.read_csv(csv_root+time_stamp1+"/"+cate+".csv")
f2=pd.read_csv(csv_root+time_stamp2+"/"+cate+".csv")
f3=pd.read_csv(csv_root+time_stamp3+"/"+cate+".csv")
f4=pd.read_csv(csv_root+time_stamp4+"/"+cate+".csv")
f5=pd.read_csv(csv_root+time_stamp5+"/"+cate+".csv")
f6=pd.read_csv(csv_root+time_stamp6+"/"+cate+".csv")

f_new=pd.concat([f1,f2,f3,f4,f5,f6])
# name=time_stamp1+'|'+time_stamp2+'|'+time_stamp3+'|'+time_stamp4+'|'+time_stamp5+'|'+time_stamp6e
name = 'test'
# name = 'train'
if not os.path.exists(csv_root+name):
    os.mkdir(csv_root+name)

# %%
f_new.to_csv(csv_root+name+"/"+cate+".csv",index=False)
f_new
# Out:
#        Vehicle_ID  Frame_ID  Local_X   Local_Y  v_Vel  v_Acc  Lane_ID   x_v  \
# 0            2147      7203   39.593  1606.652  19.97   1.39        4  0.26
# 1            2147      7204   39.593  1608.455  20.87  11.20        4  0.00
# 2            2147      7205   39.596  1610.567  22.43  11.20        4  0.03
# 3            2147      7206   39.627  1612.867  24.06   4.83        4  0.31
# 4            2147      7207   39.643  1615.304  24.66   2.58        4  0.16
# 5            2147      7208   39.661  1617.789  24.61   6.10        4  0.18
# 6            2147      7209   39.678  1620.317  26.11 -11.20        4  0.17
# 7            2147      7210   39.709  1623.100  23.20 -11.20        4  0.31
# 8            2147      7211   39.713  1625.133  22.13  11.20        4  0.04
# 9            2147      7212   39.706  1627.146  25.50  11.20        4 -0.07
# 10           2147      7202   39.567  1604.295  22.98 -11.20        4  0.25
# ...
